# %% [markdown]
# # 2025-11-23 Daily Experiments & Metric Evaluation
#
# 오늘의 실험 및 지표 평가 노트북입니다. (Korean language support included)
#
# ---
#
# 이 노트북은 환경 초기화, 필수 라이브러리 임포트, 버전 확인, 디스플레이 설정, 환경 테스트를 포함합니다.

# %% [markdown]
# ## 1. Import Essential Libraries
#
# 필수 라이브러리를 임포트합니다. (numpy, pandas, matplotlib, konlpy 등)

# %%
# 필수 라이브러리 임포트
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from konlpy.tag import Okt

# 기타 자주 사용하는 라이브러리
import seaborn as sns
import platform

# %% [markdown]
# ## 2. Verify Python and Library Versions
#
# 파이썬 및 주요 라이브러리 버전을 확인합니다.

# %%
print(f"Python: {sys.version}")
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"konlpy: {Okt.__module__}")

# %% [markdown]
# ## 3. Set Up Notebook Display Options
#
# 판다스와 맷플롯립의 디스플레이 옵션을 설정합니다.

# %%
# 판다스와 맷플롯립 디스플레이 옵션 설정
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 120)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 4. Test Notebook Environment
#
# 간단한 연산 및 시각화로 노트북 환경이 정상 동작하는지 확인합니다.

# %%
# 간단한 연산 및 시각화 테스트
print('2 + 2 =', 2 + 2)

# 샘플 데이터 시각화
data = pd.DataFrame({'x': np.arange(5), 'y': np.random.randn(5)})
plt.figure(figsize=(6,4))
sns.barplot(x='x', y='y', data=data)
plt.title('샘플 바 플롯 (Sample Bar Plot)')
plt.show()
