# %% [markdown]
# ## 0. Provision AWS Resources (Run Once)
#
# Run the following cell to create all required AWS resources (S3, Kinesis, DynamoDB, IAM, Kinesis Data Analytics) using the provided setup script. **This step incurs AWS costs.**

# %%
# Run setup.sh to provision AWS resources
# !bash setup.sh

# %% [markdown]
# ## 1. View and Edit Producer Script
# Below is the current content of `scripts/producer.py`. Edit as needed, then run the next cell to simulate streaming.

# %%
# Display producer.py for review/editing
with open('scripts/producer.py', 'r', encoding='utf-8') as f:
    print(f.read())
