# %% [markdown]
# ## 1. Preview Local Data
#
# Load and preview your local data file. This will be the source for your simulated real-time stream.

# %%
import pandas as pd

data_path = '../../02_ml_basics/data/ratings_train.txt'  # Update path if needed
try:
    df = pd.read_csv(data_path, sep='\t', encoding='utf-8')
except Exception:
    df = pd.read_csv(data_path, sep=',', encoding='utf-8')

print('Shape:', df.shape)
df.head()

# %% [markdown]
# ## 2. Simulate Real-Time Streaming
#
# Send each row as a simulated event, with a short delay between each. You can later swap the print/send logic to push to AWS Kinesis or another endpoint.
