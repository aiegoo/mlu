# %%
import pandas as pd
raw_path = '../../02_ml_basics/data/ratings_train.txt'  # Adjust as needed
try:
    df_raw = pd.read_csv(raw_path, sep='\t', encoding='utf-8')
except Exception:
    df_raw = pd.read_csv(raw_path, sep=',', encoding='utf-8')
print('Raw shape:', df_raw.shape)
df_raw.head()

# %% [markdown]
# ## 2. Preview Local Processed Data
# Load and inspect the processed data (if available).

# %%
try:
    df_proc = pd.read_csv('processed/train_processed.csv')
    print('Processed shape:', df_proc.shape)
    df_proc.head()
except Exception as e:
    print('Processed data not found:', e)
